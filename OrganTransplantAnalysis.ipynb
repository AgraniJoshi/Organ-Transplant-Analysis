# %%
# !unzip _Data.zip
# %ls
# Out:
# Archive:  _Data.zip
#   inflating: TOTAL NO. OF LIVER  DONATED (DECEASED+LIVING).xlsx
#   inflating: TOTAL NO. OF PANCREAS  DONATED BY DECEASED DONORS.xlsx
#   inflating: Total number of small intestines donated by deceased organ donors in india 2014-2021.xlsx
#   inflating: Data on organ transplantation in india 2014-2021.xlsx
#   inflating: OrgansneededinSEP2024.xlsx
#   inflating: Pledge Registration State Wise.xlsx
#   inflating: Registration by Age.xlsx
#   inflating: Registration by Gender.xlsx
#   inflating: Registration by Type.xlsx
#   inflating: TOTAL NO. OF  HEARTS   DONATED BY DECEASED DONORS.xlsx
#   inflating: TOTAL NO. OF  LUNGS   DONATED BY DECEASED DONORS.xlsx
#   inflating: TOTAL NO. OF KIDNEYS DONATED (DECEASED+LIVING).xlsx
# 'Data on organ transplantation in india 2014-2021.xlsx'
#  _Data.zip
#  OrgansneededinSEP2024.xlsx
# 'Pledge Registration State Wise.xlsx'
# 'Registration by Age.xlsx'
# 'Registration by Gender.xlsx'
# 'Registration by Type.xlsx'
# ...

# %%
import pandas as pd
import plotly.express as px
State_Oath=pd.read_excel("/content/Pledge Registration State Wise.xlsx")

State_Oath.head()
# Out:
#    Unnamed: 0      STATE        CITY  TOTAL
# 0         NaN     LADAKH  LEH LADAKH     12
# 1         NaN     LADAKH      KARGIL      8
# 2         NaN  RAJASTHAN      JAIPUR   2935
# 3         NaN  RAJASTHAN   DUNGARPUR   2874
# 4         NaN  RAJASTHAN   JHUNJHUNU   2708

# %%
Age=pd.read_excel("/content/Registration by Age.xlsx")

Age.head()
# Out:
#    Unnamed: 0        STATE    18-30    30-45   45-60     60+
# 0         NaN          NaN      NaN      NaN     NaN     NaN
# 1         NaN          NaN      NaN      NaN     NaN     NaN
# 2         NaN    RAJASTHAN  11473.0  18534.0  7970.0  2354.0
# 3         NaN  MAHARASHTRA   6265.0  15603.0  7638.0  1237.0
# 4         NaN    KARNATAKA   5802.0  11324.0  5529.0  1715.0

# %%
Gender=pd.read_excel("/content/Registration by Gender.xlsx")

Gender.head()
# Out:
#    Unnamed: 0        STATE     MALE   FEMALE
# 0         NaN          NaN      NaN      NaN
# 1         NaN          NaN      NaN      NaN
# 2         NaN    RAJASTHAN  23371.0  16960.0
# 3         NaN  MAHARASHTRA  13816.0  16894.0
# 4         NaN    KARNATAKA  10851.0  13517.0

# %%
Type=pd.read_excel("/content/Registration by Type.xlsx")

Type.head()
# Out:
#    Unnamed: 0        STATE   Organ  Tissues     Both
# 0         NaN          NaN     NaN      NaN      NaN
# 1         NaN          NaN     NaN      NaN      NaN
# 2         NaN    RAJASTHAN  6288.0   5366.0  27684.0
# 3         NaN  MAHARASHTRA  2827.0   1973.0  24891.0
# 4         NaN    KARNATAKA  2970.0   7168.0  13680.0

# %%
heart=pd.read_excel("/content/TOTAL NO. OF  HEARTS   DONATED BY DECEASED DONORS.xlsx")
heart.head()
# Out:
#    YEAR  TOTAL NO. OF  HEARTS   DONATED BY DECEASED DONORS
# 0  2014                                                 53
# 1  2015                                                118
# 2  2016                                                216
# 3  2017                                                237
# 4  2018                                                241

# %%
Lungs=pd.read_excel("/content/TOTAL NO. OF  LUNGS   DONATED BY DECEASED DONORS.xlsx")
Lungs.head()
# Out:
#    YEAR  TOTAL NO. OF  LUNGS   DONATED BY DECEASED DONORS
# 0  2014                                                15
# 1  2015                                                51
# 2  2016                                                73
# 3  2017                                               106
# 4  2018                                               191

# %%
Kidneys=pd.read_excel("/content/TOTAL NO. OF KIDNEYS DONATED (DECEASED+LIVING).xlsx")
Kidneys.head()
# Out:
#    YEAR  TOTAL NO. OF KIDNEYS DONATED (DECEASED+LIVING)   \
# 0  2014                                             5512
# 1  2015                                             6555
# 2  2016                                             6958
# 3  2017                                             7334
# 4  2018                                             7936
#
#    TOTAL NO. OF KIDNEYS  DONATED BY DECEASED ORGAN DONORS  \
# 0                                                628
# 1                                                984
# 2                                               1261
# 3                                               1169
# 4                                               1164
#
#    TOTAL NO. OF KIDNEYS  DONATED BY LIVING ORGAN DONORS
# 0                                               4884
# 1                                               5571
# 2                                               5697
# 3                                               6165
# ...

# %%
Liver=pd.read_excel("/content/TOTAL NO. OF LIVER  DONATED (DECEASED+LIVING).xlsx")
Liver.head()
# Out:
#    YEAR  TOTAL NO. OF LIVER DONATED (DECEASED+LIVING)   \
# 0  2014                                           1327
# 1  2015                                           1616
# 2  2016                                           1754
# 3  2017                                           1843
# 4  2018                                           1945
#
#    TOTAL NO. OF LIVER  DONATED BY DECEASED ORGAN DONORS  \
# 0                                                325
# 1                                                498
# 2                                                694
# 3                                                579
# 4                                                631
#
#    TOTAL NO. OF LIVER  DONATED BY LIVING ORGAN DONORS
# 0                                               1002
# 1                                               1118
# 2                                               1059
# 3                                               1264
# ...

# %%
Pancreas=pd.read_excel("/content/TOTAL NO. OF PANCREAS  DONATED BY DECEASED DONORS.xlsx")
Pancreas.head()
# Out:
#    YEAR  TOTAL NO. OF Pancreas  DONATED BY DECEASED DONORS
# 0  2014                                                  7
# 1  2015                                                  6
# 2  2016                                                 20
# 3  2017                                                 18
# 4  2018                                                 25

# %%
SmallIntes=pd.read_excel("/content/Total number of small intestines donated by deceased organ donors in india 2014-2021.xlsx")
SmallIntes.head()
# Out:
#    YEAR  TOTAL NO. OF SMALL INTESTINES DONATED BY DECEASED DONORS
# 0  2014                                                  2
# 1  2015                                                  2
# 2  2016                                                  1
# 3  2017                                                  1
# 4  2018                                                  2

# %%
State_Oath.groupby('STATE')['TOTAL'].mean()
# Out:
# STATE
# ANDAMAN AND NICOBAR ISLANDS                       10.333333
# ANDHRA PRADESH                                   218.518519
# ARUNACHAL PRADESH                                  0.880000
# ASSAM                                             29.823529
# BIHAR                                             52.842105
# CHANDIGARH                                       482.000000
# CHHATTISGARH                                      37.500000
# DELHI                                            265.000000
# GOA                                              122.500000
# GUJARAT                                          297.424242
# HARYANA                                          120.045455
# HIMACHAL PRADESH                                 114.750000
# JAMMU AND KASHMIR                                 68.200000
# JHARKHAND                                         59.708333
# KARNATAKA                                        740.562500
# KERALA                                           205.714286
# ...

# %%
Gender.groupby('STATE')['MALE'].mean()
# Out:
# STATE
# ANDAMAN AND NICOBAR ISLANDS                        19.0
# ANDHRA PRADESH                                   2936.0
# ARUNACHAL PRADESH                                  11.0
# ASSAM                                             800.0
# BIHAR                                            1676.0
# CHANDIGARH                                        323.0
# CHHATTISGARH                                      676.0
# DELHI                                            1700.0
# GOA                                               135.0
# GUJARAT                                          5302.0
# HARYANA                                          1602.0
# HIMACHAL PRADESH                                  873.0
# JAMMU AND KASHMIR                                 869.0
# JHARKHAND                                         917.0
# KARNATAKA                                       10851.0
# KERALA                                           1409.0
# LADAKH                                              9.0
# ...

# %%
Gender.groupby('STATE')['FEMALE'].mean()
# Out:
# STATE
# ANDAMAN AND NICOBAR ISLANDS                        12.0
# ANDHRA PRADESH                                   3086.0
# ARUNACHAL PRADESH                                  11.0
# ASSAM                                             218.0
# BIHAR                                             339.0
# CHANDIGARH                                        159.0
# CHHATTISGARH                                      438.0
# DELHI                                            1215.0
# GOA                                               110.0
# GUJARAT                                          4542.0
# HARYANA                                          1040.0
# HIMACHAL PRADESH                                  543.0
# JAMMU AND KASHMIR                                 503.0
# JHARKHAND                                         543.0
# KARNATAKA                                       13517.0
# KERALA                                           1474.0
# LADAKH                                             11.0
# ...

# %%
Age.groupby('STATE')['18-30'].mean().plot.line()
# Out:
# <Axes: xlabel='STATE'>

# %%
Age.groupby('STATE')['30-45'].mean().plot.line()
# Out:
# <Axes: xlabel='STATE'>

# %%
Age.groupby('STATE')['45-60'].mean().plot.line()
# Out:
# <Axes: xlabel='STATE'>

# %%
Age.groupby('STATE')['60+'].mean().plot.line()
# Out:
# <Axes: xlabel='STATE'>

# %%
State_Oath.groupby('STATE')['TOTAL'].mean().plot.bar()
# Out:
# <Axes: xlabel='STATE'>

# %%
# Assuming Gender DataFrame has 'STATE' and 'FEMALE' columns
fig = px.scatter(Gender, y="FEMALE", x="STATE")
fig.update_layout(scattermode="group")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Assuming Gender DataFrame has 'STATE' and 'FEMALE' columns
fig = px.scatter(Gender, y="MALE", x="STATE")
fig.update_layout(scattermode="group")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
Gender.drop(Gender[Gender['STATE'] == "NOT YET ASSIGNED"].index, inplace=True)

# %%
fig = px.scatter(Gender, y="FEMALE", x="STATE")
fig.update_layout(scattermode="group")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(Gender, y="MALE", x="STATE")
fig.update_layout(scattermode="group")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(Age, y="60+", x="STATE")
fig.update_layout(scattermode="group")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
Age.drop(Age[Age['STATE'] == "NOT YET ASSIGNED"].index, inplace=True)

# %%
fig = px.scatter(Age, y="60+", x="STATE")
fig.update_layout(scattermode="group")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
Pancreas.isnull()
# Out:
#     YEAR  TOTAL NO. OF Pancreas  DONATED BY DECEASED DONORS
# 0  False                                              False
# 1  False                                              False
# 2  False                                              False
# 3  False                                              False
# 4  False                                              False
# 5  False                                              False
# 6  False                                              False
# 7  False                                              False

# %%
heart.isnull()
# Out:
#     YEAR  TOTAL NO. OF  HEARTS   DONATED BY DECEASED DONORS
# 0  False                                              False
# 1  False                                              False
# 2  False                                              False
# 3  False                                              False
# 4  False                                              False
# 5  False                                              False
# 6  False                                              False
# 7  False                                              False

# %%
State_Oath.isnull()
# Out:
#      Unnamed: 0  STATE   CITY  TOTAL
# 0          True  False  False  False
# 1          True  False  False  False
# 2          True  False  False  False
# 3          True  False  False  False
# 4          True  False  False  False
# ..          ...    ...    ...    ...
# 756        True  False  False  False
# 757        True  False  False  False
# 758        True  False  False  False
# 759        True  False  False  False
# 760        True  False  False  False
#
# [761 rows x 4 columns]

# %%
State_Oath.isnull().sum()
# Out:
# Unnamed: 0    761
# STATE           0
# CITY            0
# TOTAL           0
# dtype: int64

# %%
State_Oath.dtypes
# Out:
# Unnamed: 0    float64
# STATE          object
# CITY           object
# TOTAL           int64
# dtype: object

# %%
State_Oath.dropna(inplace=True)

# %%
State_Oath.dtypes
# Out:
# Unnamed: 0    float64
# STATE          object
# CITY           object
# TOTAL           int64
# dtype: object

# %%
State_Oath.isnull().sum()
# Out:
# Unnamed: 0    0
# STATE         0
# CITY          0
# TOTAL         0
# dtype: int64
